# %% [markdown]
# The options under Type detection and Realtionships should be unchecked. <br> Relationships should be defined by developer based on his knowledge of the dataset <br> It is important to note here that time intelligence

# %% [markdown]
# ![image.png](attachment:image.png)
